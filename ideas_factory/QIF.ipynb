# %%
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, BasicAer,execute
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator,AerSimulator
#from qiskit.providers.aer import AerSimulator
from qiskit_aer.noise import NoiseModel,thermal_relaxation_error,pauli_error,depolarizing_error
from qiskit import quantum_info as qi
from qiskit.opflow import X,Y,Z,I,PauliExpectation,StateFn,CircuitStateFn,CircuitSampler
from qiskit.utils import QuantumInstance
from random import randint
# Loading your IBM Quantum account(s)
#provider = IBMQ.load_account()
#backend = provider.get_backend('ibmq_qasm_simulator')

# %%
state = QuantumCircuit(1)

#phase_shift(np.pi/4,state)
state.u(2*np.pi/4,np.pi/2,-1*np.pi/2,0)
st = CircuitStateFn(state)
#
#phase_shift
measurable_expression = StateFn(Y, is_measurement=True).compose(st)

# define your backend or quantum instance (where you can add settings)
backend = Aer.get_backend('qasm_simulator') 
q_instance = QuantumInstance(backend, shots=1024)

# define the state to sample
measurable_expression = StateFn(X, is_measurement=True).compose(st) 

# convert to expectation value
expectation = PauliExpectation().convert(measurable_expression)  

# get state sampler (you can also pass the backend directly)
sampler = CircuitSampler(q_instance).convert(expectation) 

# evaluate
print('Sampled:', sampler.eval().real)
# Out:
# Sampled: -0.035156249999999944

# %%
def phase_shift_loop_mixed(n,angle,init_state,expect,shots,backend,noise_flag,tau=0.1,p_meas=0.01):
    '''this will run the phase shift n times. Will then execute for the number of shots provided'''
    a = 0
    for i in range(shots):
        a+= randint(0,1)
    
    state = QuantumCircuit(1,1)

    L= []
    for i in range(1,n):
        phase_shift_X(angle,state)
    apply_unitary(expect,state)
    
    state.measure(0,0)
    error = thermal_relaxation_error(tau,tau,n/shots)
    error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
    noise_model = NoiseModel()
    noise_model.add_all_qubit_quantum_error(error, ['u'])

    noise_model.add_all_qubit_quantum_error(error_meas, "measure")
 
    basis_gates = noise_model.basis_gates

    coupling_map = backend.configuration().coupling_map
 
    if noise_flag:
        job_simulator = execute(state, backend,shots=a,coupling_map=coupling_map,basis_gates=basis_gates,noise_model=noise_model)
    else:
        job_simulator = execute(state, backend, shots=a)


   
    result_simulator = job_simulator.result()
    L.append(result_simulator.get_counts(state))

    state = QuantumCircuit(1,1)

    for i in range(1,n):
        phase_shift_X(angle,state)
    apply_unitary(expect,state)
    
    state.measure(0,0)

        if noise_flag:
        job_simulator = execute(state, backend,shots=1000-a,coupling_map=coupling_map,basis_gates=basis_gates,noise_model=noise_model)
    else:
        job_simulator = execute(state, backend, shots=1000-a)
   
    result_simulator = job_simulator.result()
    L.append(result_simulator.get_counts(state))


    return L

def Cont():
    A = randint(400,600)
    qc2 = QuantumCircuit(1,1)
    qc2.reset(0)
    if A == 1:
        qc2.x(0)
    return qc2
tau = 2
prop= 0.1
p_meas = 0.1
error2 = depolarizing_error(prop, 1)
error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
ntot =30
average = 100
angle = np.pi/ntot*8
L3 = []
Ltot = []
qc1 = QuantumCircuit(1)
for j in range(average):
    L=[]
    L2 = []
    for n in range(ntot):
        qc1 = Cont()
        for i in range(n):
            qc1.u(angle,np.pi/2,-np.pi/2,0)
        qc1.measure(0,0)
        #qc2 = meas.compose(qc1, range(1), front=True)
        error = thermal_relaxation_error(tau,tau,n/ntot)
        noise_model = NoiseModel()
        noise_model.add_all_qubit_quantum_error(error, ['u'])
        noise_model.add_all_qubit_quantum_error(error2, ['u'])
        noise_model.add_all_qubit_quantum_error(error_meas, "measure") 
        basis_gates = noise_model.basis_gates

        res = execute(qc1, AerSimulator(),shots=1,basis_gates=basis_gates,noise_model=noise_model).result()
        L.append(res.get_counts(qc1))
        if '0' in L[n]:
            nup = L[n]['0']/average
        else:
            nup = 0
        if '1' in L[n]:
            ndown = L[n]['1']/average
        else:
            ndown = 0

        L2.append(nup-ndown)
    L3.append(L2)
for n in range(ntot):
    w=0
    for k in range(average):
        w = w + L3[k][n]
    Ltot.append(w)
# Out:
#   Cell In [177], line 44
#     if noise_flag:
#     ^
# IndentationError: unexpected indent

# %%
def phase_shift_loop_down(n,angle,init_state,expect,shots,backend,noise_flag,tau=0.1,p_meas=0.01):
    '''this will run the phase shift n times. Will then execute for the number of shots provided'''
    a = 0
    for i in range(shots):
        a+= randint(0,1)
    
    state = QuantumCircuit(1,1)

    L= []
    for i in range(1,n):
        phase_shift_X(angle,state)
    apply_unitary(expect,state)
    
    state.measure(0,0)
    error = thermal_relaxation_error(tau,tau,n/shots)
    error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
    noise_model = NoiseModel()
    noise_model.add_all_qubit_quantum_error(error, ['u'])

    noise_model.add_all_qubit_quantum_error(error_meas, "measure")
 
    basis_gates = noise_model.basis_gates

    coupling_map = backend.configuration().coupling_map
 
    if noise_flag:
        job_simulator = execute(state, backend,shots=shots,coupling_map=coupling_map,basis_gates=basis_gates,noise_model=noise_model)
    else:
        job_simulator = execute(state, backend, shots=shots)


   
    result_simulator = job_simulator.result()
    L.append(result_simulator.get_counts(state))

    return L

def phase_shift_loop_up(n,angle,init_state,expect,shots,backend,noise_flag,tau=0.1,p_meas=0.01):
    '''this will run the phase shift n times. Will then execute for the number of shots provided'''
    a = 0
    for i in range(shots):
        a+= randint(0,1)
    
    state = QuantumCircuit(1,1)
    state.x(0)
    L= []
    for i in range(1,n):
        phase_shift_X(angle,state)
    apply_unitary(expect,state)
    
    state.measure(0,0)
    error = thermal_relaxation_error(tau,tau,n/shots)
    error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
    noise_model = NoiseModel()
    noise_model.add_all_qubit_quantum_error(error, ['u'])

    noise_model.add_all_qubit_quantum_error(error_meas, "measure")
 
    basis_gates = noise_model.basis_gates

    coupling_map = backend.configuration().coupling_map
 
    if noise_flag:
        job_simulator = execute(state, backend,shots=shots,coupling_map=coupling_map,basis_gates=basis_gates,noise_model=noise_model)
    else:
        job_simulator = execute(state, backend, shots=shots)


   
    result_simulator = job_simulator.result()
    L.append(result_simulator.get_counts(state))

    return L

def phase_shift_loop_master_mixed(angle,n,init_state,expect,shots,backend,noise_flag):
    '''this will run the phase loop for each n'''
    results = []
    for i in range(1,n):
        #state = QuantumCircuit(1,1)
        a = 0
        for i in range(shots):
            a+= randint(0,1)
        r_down = phase_shift_loop_down(i,angle,init_state,expect,a,backend,noise_flag)
        r_up = phase_shift_loop_up(i,angle,init_state,expect,(shots-a),backend,noise_flag)
 
        r_down = r_down[0]
        r_up = r_up[0]
        #r0 = r[0]
    
        n_up = (1*r_up['1']) if '1' in r_up.keys() else 0
        n_up += (1*r_down['1']) if '1' in r_down.keys() else 0
        n_down = (-1*r_up['0']) if '0' in r_up.keys() else 0
        n_down += (-1*r_down['0']) if '0' in r_down.keys() else 0
        
        #n_up = (1*r[0]['0']) if '0' in r0.keys() else 0
        #n_down = (-1*r[0]['1']) if '1' in r0.keys() else 0
        results.append(((n_up+n_down)/shots))
        #print(results)
    return results

def my_plot_mixed(angle,n,init_state,expect,shots = 1000,backend=backend, noise_flag=False):
    '''function to plot my phase shift results i.e. expecatation value of sigma z over time'''
    results = phase_shift_loop_master_mixed(angle,n,init_state,expect,shots,backend,noise_flag)
    plot_expectation_value(range(1,n),results, ylabel='$\sigma_z$',x_range=[0,n],xlabel = 'n')

# %%
my_plot_mixed(np.pi/20,80,init_Y,'sigma_X',shots = 500,backend=backend,noise_flag=True)

# %%
plot_expectation_value(range(30),Ltot, ylabel='$\sigma_z$',x_range=[0,n],xlabel = 'n')

# %%
# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_qasm_simulator')
backend = AerSimulator()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.style as style
import numpy.linalg as linalg
import scipy
from scipy.linalg import expm , cosm, sinm
style.use('seaborn-v0_8-bright')

# %%
font = {'family': 'serif',
    'color':  'forestgreen',
    'weight': 'normal',
    'size': 22,
    }

    

def plot_expectation_value(x,y,ylabel,xlabel = '$\omega$t',fig_size=(10.0,7.0),plot_grid=True,x_range=[0,8*np.pi],colour='b'):
    plt.figure(figsize = fig_size)
    plt.plot(x,y,colour)
    plt.xlim(x_range)
    plt.grid(plot_grid)
    plt.xlabel(xlabel, fontdict=font)
    plt.ylabel('<'+ylabel+'>', fontdict=font)
    plt.title(f'Expectation Value of {ylabel}',fontdict=font)

# %%
qc = QuantumCircuit(1,1)

def phase_shift_X(angle,state):
    return state.u(2*angle,np.pi/2,-1*np.pi/2,0)

def phase_shift_Y(angle,state):
    return state.u(2*angle,np.pi,-1*np.pi,0)

def phase_shift_Z(angle,state):
    return state.u(0,-1*angle,-1*angle,0)


def apply_unitary(expect,state):
    if expect == 'sigma_X':
        return state.u(np.pi/2,np.pi,-1*np.pi,0)
    elif expect == 'sigma_Y':
        return state.u(3*np.pi/2,np.pi/2,-1*np.pi/2,0)
    elif expect == 'sigma_Z':
        return state

def phase_shift_loop(n,angle,init_state,expect,shots,backend,noise_flag,tau=0.1,p_meas=0.01):
    '''this will run the phase shift n times. Will then execute for the number of shots provided'''

    state = init_state()
    L= []
    for i in range(1,n):
        phase_shift_X(angle,state)
    apply_unitary(expect,state)
    
    state.measure(0,0)
    error = thermal_relaxation_error(tau,tau,n/shots)
    error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
    noise_model = NoiseModel()
    noise_model.add_all_qubit_quantum_error(error, ['u'])

    noise_model.add_all_qubit_quantum_error(error_meas, "measure")
 
    basis_gates = noise_model.basis_gates

    coupling_map = backend.configuration().coupling_map
 
    if noise_flag:
        job_simulator = execute(state, backend,shots=shots,coupling_map=coupling_map,basis_gates=basis_gates,noise_model=noise_model)
    else:
        job_simulator = execute(state, backend, shots=shots)
   
    result_simulator = job_simulator.result()
    L.append(result_simulator.get_counts(state))
    return L



def phase_shift_loop_master(angle,n,init_state,expect,shots,backend,noise_flag):
    '''this will run the phase loop for each n'''
    results = []
    for i in range(1,n):
        #state = QuantumCircuit(1,1)
        r = phase_shift_loop(i,angle,init_state,expect,shots,backend,noise_flag)
        #print(r)
        r0 = r[0]
        n_up = (1*r[0]['0']) if '0' in r0.keys() else 0
        n_down = (-1*r[0]['1']) if '1' in r0.keys() else 0
        results.append(((n_up+n_down)/shots))
        #print(results)
    return results

#print(counts)
#x = []
#for i in range(1,1000):
#phase_shift_loop_master(np.pi/100,100,1000,QuantumCircuit(1,1))



def my_plot(angle,n,init_state,expect,shots = 1000,backend=backend, noise_flag=False):
    '''function to plot my phase shift results i.e. expecatation value of sigma z over time'''
    results = phase_shift_loop_master(angle,n,init_state,expect,shots,backend,noise_flag)
    plot_expectation_value(range(1,n),results, ylabel='$\sigma_z$',x_range=[0,n],xlabel = 'n')


def init_qubit(x,y):
    res = QuantumCircuit(1,1)
    res.initialize([x,y],res.qubits)
    return res

def init_Z():
    return init_qubit(1,0)

def init_Y():
    return init_qubit(1/np.sqrt(2), 1j*1/np.sqrt(2))

def init_X():
    return init_qubit(1/np.sqrt(2), 1/np.sqrt(2))

#init_X = init_qubit(1/np.sqrt(2), 1/np.sqrt(2))
#init_Y = init_qubit(1/np.sqrt(2), 1j*1/np.sqrt(2))
#init_Z = init_qubit(1,0)

# %%
#backend = AerSimulator()
#state = QuantumCircuit(1,1)
my_plot(np.pi/20,80,init_Y,'sigma_Y',shots = 2000,backend=backend,noise_flag=True)

# %%
my_plot(np.pi/10,20,init_X,shots = 100,backend=backend,noise_flag=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [114], line 1
# ----> 1 my_plot(np.pi/10,20,init_X,shots = 100,backend=backend,noise_flag=False)
#
# TypeError: my_plot() missing 1 required positional argument: 'expect'

# %%
#backend = provider.get_backend('ibmq_qasm_simulator')
backend = AerSimulator()
my_plot(np.pi/100,2000,shots = 500,backend=backend,noise_flag=True)

# %%
backend = AerSimulator()
my_plot(np.pi/10,30,init_Z,shots = 50,backend=backend,noise_flag=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [45], line 2
#       1 backend = AerSimulator()
# ----> 2 my_plot(np.pi/10,190,init_Z,shots = 50,backend=backend,noise_flag=True)
#
# Cell In [35], line 74, in my_plot(angle, n, init_state, shots, backend, noise_flag)
#      72 def my_plot(angle,n,init_state,shots = 1000,backend=backend, noise_flag=False):
#      73     '''function to plot my phase shift results i.e. expecatation value of sigma z over time'''
# ---> 74     results = phase_shift_loop_master(angle,n,init_state,shots,backend,noise_flag)
#      75     plot_expectation_value(range(1,n),results, ylabel='$\sigma_z$',x_range=[0,n],xlabel = 'n')
#
# Cell In [35], line 56, in phase_shift_loop_master(angle, n, init_state, shots, backend, noise_flag)
#      53 results = []
#      54 for i in range(1,n):
#      55     #state = QuantumCircuit(1,1)
# ---> 56     r = phase_shift_loop(i,angle,init_state,shots,backend,noise_flag)
#      57     #print(r)
#      58     r0 = r[0]
#
# Cell In [35], line 39, in phase_shift_loop(n, angle, init_state, shots, backend, noise_flag, tau, p_meas)
#      31 #qc = QuantumCircuit(1,1)
#      32 #phase_shift(angle,qc)
#      33 #qc.measure(0,0)
#    (...)
#      36 #error = noise.thermal_relaxation_error(tau,tau,n/shots)
#      37 #noise_model.add_all_qubit_quantum_error(error, ['u'])
#      38 if noise_flag:
# ---> 39     job_simulator = execute(state, backend,shots=shots,coupling_map=coupling_map,basis_gates=basis_gates,noise_model=noise_model)
#      40 else:
#      41     #print('here')
#      42     job_simulator = execute(state, backend, shots=shots)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\execute_function.py:299, in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     296     experiments = pass_manager.run(experiments)
#     297 else:
#     298     # transpiling the circuits using given transpile options
# --> 299     experiments = transpile(
#     300         experiments,
#     301         basis_gates=basis_gates,
#     302         coupling_map=coupling_map,
#     303         backend_properties=backend_properties,
#     304         initial_layout=initial_layout,
#     305         seed_transpiler=seed_transpiler,
#     306         optimization_level=optimization_level,
#     307         backend=backend,
#     308     )
#     310 if schedule_circuit:
#     311     experiments = schedule(
#     312         circuits=experiments,
#     313         backend=backend,
#    (...)
#     316         method=scheduling_method,
#     317     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\compiler\transpiler.py:382, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     379     for circuit, unique_args in zip(circuits, unique_transpile_args):
#     380         transpile_config, pass_manager = _combine_args(shared_args, unique_args)
#     381         output_circuits.append(
# --> 382             _serial_transpile_circuit(
#     383                 circuit,
#     384                 pass_manager,
#     385                 transpile_config["callback"],
#     386                 transpile_config["output_name"],
#     387                 transpile_config["backend_num_qubits"],
#     388                 transpile_config["faulty_qubits_map"],
#     389                 transpile_config["pass_manager_config"].backend_properties,
#     390             )
#     391         )
#     392     circuits = output_circuits
#     393 end_time = time()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\compiler\transpiler.py:475, in _serial_transpile_circuit(circuit, pass_manager, callback, output_name, num_qubits, faulty_qubits_map, backend_prop)
#     466 def _serial_transpile_circuit(
#     467     circuit,
#     468     pass_manager,
#    (...)
#     473     backend_prop=None,
#     474 ):
# --> 475     result = pass_manager.run(circuit, callback=callback, output_name=output_name)
#     476     if faulty_qubits_map:
#     477         return _remap_circuit_faulty_backend(
#     478             result,
#     479             num_qubits,
#     480             backend_prop,
#     481             faulty_qubits_map,
#     482         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\passmanager.py:528, in StagedPassManager.run(self, circuits, output_name, callback)
#     521 def run(
#     522     self,
#     523     circuits: Union[QuantumCircuit, List[QuantumCircuit]],
#     524     output_name: str = None,
#     525     callback: Callable = None,
#     526 ) -> Union[QuantumCircuit, List[QuantumCircuit]]:
#     527     self._update_passmanager()
# --> 528     return super().run(circuits, output_name, callback)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\passmanager.py:228, in PassManager.run(self, circuits, output_name, callback)
#     226     return circuits
#     227 if isinstance(circuits, QuantumCircuit):
# --> 228     return self._run_single_circuit(circuits, output_name, callback)
#     229 if len(circuits) == 1:
#     230     return self._run_single_circuit(circuits[0], output_name, callback)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\passmanager.py:283, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     271 """Run all the passes on a ``circuit``.
#     272
#     273 Args:
#    (...)
#     280     The transformed circuit.
#     281 """
#     282 running_passmanager = self._create_running_passmanager()
# --> 283 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     284 self.property_set = running_passmanager.property_set
#     285 return result
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\runningpassmanager.py:125, in RunningPassManager.run(***failed resolving arguments***)
#     123 for passset in self.working_list:
#     124     for pass_ in passset:
# --> 125         dag = self._do_pass(pass_, dag, passset.options)
#     127 circuit = dag_to_circuit(dag)
#     128 if output_name:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\runningpassmanager.py:172, in RunningPassManager._do_pass(self, pass_, dag, options)
#     170 # Run the pass itself, if not already run
#     171 if pass_ not in self.valid_passes:
# --> 172     dag = self._run_this_pass(pass_, dag)
#     174     # update the valid_passes property
#     175     self._update_valid_passes(pass_)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\runningpassmanager.py:201, in RunningPassManager._run_this_pass(self, pass_, dag)
#     198 if pass_.is_transformation_pass:
#     199     # Measure time if we have a callback or logging set
#     200     start_time = time()
# --> 201     new_dag = pass_.run(dag)
#     202     end_time = time()
#     203     run_time = end_time - start_time
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\passes\basis\unroll_custom_definitions.py:96, in UnrollCustomDefinitions.run(self, dag)
#      90         raise QiskitError(
#      91             "Cannot unroll the circuit to the given basis, %s. "
#      92             "Instruction %s not found in equivalence library "
#      93             "and no rule found to expand." % (str(self._basis_gates), node.op.name)
#      94         )
#      95     decomposition = circuit_to_dag(node.op.definition)
# ---> 96     unrolled_dag = UnrollCustomDefinitions(self._equiv_lib, self._basis_gates).run(
#      97         decomposition
#      98     )
#      99     dag.substitute_node_with_dag(node, unrolled_dag)
#     101 return dag
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\transpiler\passes\basis\unroll_custom_definitions.py:77, in UnrollCustomDefinitions.run(self, dag)
#      74         continue
#      76 try:
# ---> 77     rule = node.op.definition.data
#      78 except TypeError as err:
#      79     raise QiskitError(f"Error decomposing node {node.name}: {err}") from err
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\circuit\instruction.py:237, in Instruction.definition(self)
#     235 """Return definition in terms of other basic gates."""
#     236 if self._definition is None:
# --> 237     self._define()
#     238 return self._definition
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\circuit\library\data_preparation\state_preparation.py:111, in StatePreparation._define(self)
#     109     self.definition = self._define_from_int()
#     110 else:
# --> 111     self.definition = self._define_synthesis()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\circuit\library\data_preparation\state_preparation.py:171, in StatePreparation._define_synthesis(self)
#     161 """Calculate a subcircuit that implements this initialization
#     162
#     163 Implements a recursive initialization algorithm, including optimizations,
#    (...)
#     168 double cnots.
#     169 """
#     170 # call to generate the circuit that takes the desired vector to zero
# --> 171 disentangling_circuit = self._gates_to_uncompute()
#     173 # invert the circuit to create the desired vector from zero (assuming
#     174 # the qubits are in the zero state)
#     175 if self._inverse is False:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\circuit\library\data_preparation\state_preparation.py:276, in StatePreparation._gates_to_uncompute(self)
#     273 if np.linalg.norm(phis) != 0 and np.linalg.norm(thetas) != 0:
#     274     add_last_cnot = False
# --> 276 if np.linalg.norm(phis) != 0:
#     277     rz_mult = self._multiplex(RZGate, phis, last_cnot=add_last_cnot)
#     278     circuit.append(rz_mult.to_instruction(), q[i : self.num_qubits])
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\linalg\linalg.py:2526, in norm(x, ord, axis, keepdims)
#    2524     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2525 else:
# -> 2526     sqnorm = x.dot(x)
#    2527 ret = sqrt(sqnorm)
#    2528 if keepdims:
#
# KeyboardInterrupt:

# %%
my_plot(np.pi/20,20,init_Y,shots = 100,backend=backend,noise_flag=True)

# %%
qc = QuantumCircuit(1)
qc.initialize([1/np.sqrt(2), 1/np.sqrt(2)],qc.qubits)
qi.DensityMatrix.from_instruction(qc)
# Out:
# DensityMatrix([[0.5+0.j, 0.5+0.j],
#                [0.5+0.j, 0.5+0.j]],
#               dims=(2,))

# %%
def init_qubit(x,y):
    circ = QuantumCircuit(1)
    qc.initialize([x,y],qc.qubits)
    return qc

init_X = init_qubit(1/np.sqrt(2), 1/np.sqrt(2))
init_Y = init_qubit(1/np.sqrt(2), 1j*1/np.sqrt(2))
init_Z = init_qubit(1,0)

# %%
init_X = init_qubit(1/np.sqrt(2), 1/np.sqrt(2))
init_Y = init_qubit(1/np.sqrt(2), 1j*1/np.sqrt(2))
init_Z = init_qubit(1,0)

# %%
meas = QuantumCircuit(1,1)
meas.barrier(range(1))
meas.measure(range(1),range(1))
backend = AerSimulator()
tau = 2
prop= 0.1
p_meas = 0.1
error2 = noise.depolarizing_error(prop, 1)
error_meas = noise.pauli_error([('X',p_meas), ('I', 1 - p_meas)])
ntot =20
average = 44
L=[]
L2 = []
#error = noise.thermal_relaxation_error(tau,tau,n/ntot)
#noise_model = noise.NoiseModel()
#noise_model.add_all_qubit_quantum_error(error, ['u'])
#noise_model.add_all_qubit_quantum_error(error2, ['u'])
#noise_model.add_all_qubit_quantum_error(error_meas, "measure") 
#basis_gates = noise_model.basis_gates
#qc1 = QuantumCircuit(1)
for n in range(ntot):
    qc1 = QuantumCircuit(1)
    angle = np.pi/ntot*8
    for i in range(n):
        qc1.u(angle,np.pi/2,-np.pi/2,0)
    qc2 = meas.compose(qc1, range(1), front=True)
    error = noise.thermal_relaxation_error(tau,tau,n/ntot)
    noise_model = noise.NoiseModel()
    noise_model.add_all_qubit_quantum_error(error, ['u'])
    #noise_model.add_all_qubit_quantum_error(error, ['u'])
    #noise_model.add_all_qubit_quantum_error(error2, ['u'])
    noise_model.add_all_qubit_quantum_error(error_meas, "measure") 
    basis_gates = noise_model.basis_gates

    res = execute(qc2, Aer.get_backend('qasm_simulator'),shots=average,basis_gates=basis_gates,noise_model=noise_model).result()
    L.append(res.get_counts(qc2))
    if '0' in L[n]:
        nup = L[n]['0']/average
    else:
        nup = 0
    if '1' in L[n]:
        ndown = L[n]['1']/average
    else:
        ndown = 0

    L2.append(nup-ndown)
plot_expectation_value(range(20),L2, ylabel='$\sigma_z$',x_range=[0,n],xlabel = 'n')
